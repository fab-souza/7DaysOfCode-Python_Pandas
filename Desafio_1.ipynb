# %% [markdown]
# # Importação de dados:

# %%
import pandas as pd

# %% [markdown]
# ## Empréstimos:

# %%
emprestimo_2010_1 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20101.csv')
emprestimo_2010_2 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20102.csv')
emprestimo_2011_1 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20111.csv')
emprestimo_2011_2 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20112.csv')
emprestimo_2012_1 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20121.csv')
emprestimo_2012_2 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20122.csv')
emprestimo_2013_1 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20131.csv')
emprestimo_2013_2 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20132.csv')
emprestimo_2014_1 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20141.csv')
emprestimo_2014_2 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20142.csv')
emprestimo_2015_1 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20151.csv')
emprestimo_2015_2 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20152.csv')
emprestimo_2016_1 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20161.csv')
emprestimo_2016_2 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20162.csv')
emprestimo_2017_1 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20171.csv')
emprestimo_2017_2 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20172.csv')
emprestimo_2018_1 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20181.csv')
emprestimo_2018_2 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20182.csv')
emprestimo_2019_1 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20191.csv')
emprestimo_2019_2 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20192.csv')
emprestimo_2020_1 = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20201.csv')

# %%
emprestimos = pd.concat([emprestimo_2010_1, emprestimo_2010_2, emprestimo_2011_1, emprestimo_2011_2, 
                         emprestimo_2012_1, emprestimo_2012_2, emprestimo_2013_1, emprestimo_2013_2, 
                         emprestimo_2014_1, emprestimo_2014_2, emprestimo_2015_1, emprestimo_2015_2, 
                         emprestimo_2016_1, emprestimo_2016_2, emprestimo_2017_1, emprestimo_2017_2, 
                         emprestimo_2018_1, emprestimo_2018_2, emprestimo_2019_1, emprestimo_2019_2, 
                         emprestimo_2020_1])

# %%
emprestimos.sample(3)
# Out:
#        id_emprestimo codigo_barras                 data_renovacao  \
# 52414        2633045    2014058897  2018/04/20 09:26:17.891000000
# 60365        2640998    2012009825  2018/04/30 21:39:23.754000000
# 78598        2861500    2017036680                            NaN
#
#                      data_emprestimo                 data_devolucao  \
# 52414  2018/04/05 18:44:07.182000000  2018/05/10 16:14:37.000000000
# 60365  2018/04/17 12:53:53.036000000  2018/05/08 13:33:23.000000000
# 78598  2019/05/22 10:35:32.372000000  2019/06/06 20:32:12.000000000
#
#        matricula_ou_siape tipo_vinculo_usuario
# 52414        2.016011e+10   ALUNO DE GRADUAÇÃO
# 60365        2.015010e+09   ALUNO DE GRADUAÇÃO
# 78598        2.015054e+09   ALUNO DE GRADUAÇÃO

# %%
emprestimos.shape
# Out:
# (2258018, 7)

# %%
emprestimos.dtypes
# Out:
# id_emprestimo             int64
# codigo_barras            object
# data_renovacao           object
# data_emprestimo          object
# data_devolucao           object
# matricula_ou_siape      float64
# tipo_vinculo_usuario     object
# dtype: object

# %%
emprestimos[['data_renovacao', 'data_emprestimo', 'data_devolucao']] = emprestimos[['data_renovacao', 
                                                                                    'data_emprestimo', 
                                                                                    'data_devolucao']].apply(pd.to_datetime)
emprestimos['matricula_ou_siape'] = emprestimos.matricula_ou_siape.astype(str)
emprestimos.sample(3)
# Out:
#         id_emprestimo codigo_barras          data_renovacao  \
# 14855         2702607    2012036700 2018-08-20 14:32:09.775
# 344           1282844    2012034109                     NaT
# 101729        1501795    2012067672                     NaT
#
#                data_emprestimo      data_devolucao matricula_ou_siape  \
# 14855  2018-08-06 10:41:48.135 2018-08-29 20:22:28       2012941680.0
# 344    2012-07-02 20:35:08.323 2012-07-12 08:54:48       2011307082.0
# 101729 2013-05-09 15:34:41.160 2013-05-15 15:01:18       2010018583.0
#
#        tipo_vinculo_usuario
# 14855    ALUNO DE GRADUAÇÃO
# 344     ALUNO MÉDIO/TÉCNICO
# 101729   ALUNO DE GRADUAÇÃO

# %%
emprestimos.dtypes
# Out:
# id_emprestimo                    int64
# codigo_barras                   object
# data_renovacao          datetime64[ns]
# data_emprestimo         datetime64[ns]
# data_devolucao          datetime64[ns]
# matricula_ou_siape              object
# tipo_vinculo_usuario            object
# dtype: object

# %%
emprestimos.isna().sum()
# Out:
# id_emprestimo                 0
# codigo_barras                 0
# data_renovacao          1285720
# data_emprestimo               0
# data_devolucao             6471
# matricula_ou_siape            0
# tipo_vinculo_usuario          0
# dtype: int64

# %% [markdown]
# ## Acervo:

# %%
acervo = pd.read_parquet('/content/dados_exemplares.parquet')
acervo.head()
# Out:
#        id_exemplar codigo_barras            colecao  \
# index
# 0                5       L000003  Acervo Circulante
# 1                4       L000002  Acervo Circulante
# 2                3       L000001  Acervo Circulante
# 3                7       L000114  Acervo Circulante
# 5               10       L000041  Acervo Circulante
#
#                            biblioteca status_material  localizacao  \
# index
# 0      Biblioteca Central Zila Mamede         REGULAR          694
# 1      Biblioteca Central Zila Mamede         REGULAR          688
# 2      Biblioteca Central Zila Mamede        ESPECIAL          638
# 3      Biblioteca Central Zila Mamede         REGULAR          616
# 5      Biblioteca Central Zila Mamede        ESPECIAL          657
#
#        registro_sistema
# index
# 0                     1
# 1                     1
# 2                     1
# 3                     5
# 5                    15

# %%
acervo.sample(5)
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 406136      1021441    2012062722         Multimeios
# 261463       259614    2008032080  Acervo Circulante
# 503782      1213189    2016001046  Acervo Circulante
# 545643      1343826    2018031319           Folhetos
# 69797       1194550    2015022909  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 406136  Biblioteca Setorial Pe. Jaime Diniz - Escola d...        ESPECIAL
# 261463  Biblioteca Setorial do Centro de Ciências Huma...         REGULAR
# 503782                     Biblioteca Central Zila Mamede         REGULAR
# 545643                     Biblioteca Central Zila Mamede         REGULAR
# 69797   Biblioteca Setorial Pe. Jaime Diniz - Escola d...         REGULAR
#
#         localizacao  registro_sistema
# index
# 406136          336            187898
# 261463          648            112264
# 503782          540            228129
# ...

# %%
acervo.shape
# Out:
# (546237, 7)

# %%
acervo.dtypes
# Out:
# id_exemplar          int64
# codigo_barras       object
# colecao             object
# biblioteca          object
# status_material     object
# localizacao          int64
# registro_sistema     int64
# dtype: object

# %%
acervo.isna().sum()
# Out:
# id_exemplar         0
# codigo_barras       0
# colecao             0
# biblioteca          0
# status_material     0
# localizacao         0
# registro_sistema    0
# dtype: int64

# %% [markdown]
# # Merge:

# %%
teste = pd.read_csv('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20201.csv')
teste.shape
# Out:
# (26561, 7)

# %%
teste.merge(acervo, how = 'inner', on = 'codigo_barras')
# Out:
#        id_emprestimo codigo_barras                 data_renovacao  \
# 0            2962509    2007005628                            NaN
# 1            2962511    2012008328                            NaN
# 2            2962852    2012008328                            NaN
# 3            2962512    2012055016  2020/01/17 09:56:18.380000000
# 4            2962513       L197391  2020/01/17 23:50:18.862000000
# ...              ...           ...                            ...
# 25605        2989076    2019014718                            NaN
# 25606        2989077    2014012921                            NaN
# 25607        2989079    2012010451                            NaN
# 25608        2989089    2010048023                            NaN
# 25609        2989090    2013106838                            NaN
#
#                      data_emprestimo                 data_devolucao  \
# 0      2020/01/02 08:17:30.290000000  2020/01/07 11:14:07.000000000
# ...

# %%
teste.merge(acervo, how = 'left', on = 'codigo_barras')
# Out:
#        id_emprestimo codigo_barras                 data_renovacao  \
# 0            2962509    2007005628                            NaN
# 1            2962510       L202802                            NaN
# 2            2962511    2012008328                            NaN
# 3            2962512    2012055016  2020/01/17 09:56:18.380000000
# 4            2962513       L197391  2020/01/17 23:50:18.862000000
# ...              ...           ...                            ...
# 26631        2989086    2008047044                            NaN
# 26632        2989087    2008047047                            NaN
# 26633        2989088    2010052905                            NaN
# 26634        2989089    2010048023                            NaN
# 26635        2989090    2013106838                            NaN
#
#                      data_emprestimo                 data_devolucao  \
# 0      2020/01/02 08:17:30.290000000  2020/01/07 11:14:07.000000000
# ...

# %%
teste.merge(acervo, how = 'right', on = 'codigo_barras')
# Out:
#         id_emprestimo codigo_barras data_renovacao data_emprestimo  \
# 0                 NaN       L000003            NaN             NaN
# 1                 NaN       L000002            NaN             NaN
# 2                 NaN       L000001            NaN             NaN
# 3                 NaN       L000114            NaN             NaN
# 4                 NaN       L000041            NaN             NaN
# ...               ...           ...            ...             ...
# 549749            NaN    2021011150            NaN             NaN
# 549750            NaN    2019013454            NaN             NaN
# 549751            NaN    2019012811            NaN             NaN
# 549752            NaN    2019013451            NaN             NaN
# 549753            NaN    2019012276            NaN             NaN
#
#        data_devolucao  matricula_ou_siape tipo_vinculo_usuario  id_exemplar  \
# 0                 NaN                 NaN                  NaN            5
# ...

# %% [markdown]
# Diante o resultado destes testes, achei melhor fazer a união através do *inner* e perder alguns registros, do que acabar criando dados.
#
# ---

# %%
dados = emprestimos.merge(acervo, how = 'inner', on = 'codigo_barras')
dados.head(3)
# Out:
#    id_emprestimo codigo_barras          data_renovacao  \
# 0         709684       L095049                     NaT
# 1         709684       L095049                     NaT
# 2         726965       L095049 2010-03-31 12:41:08.684
#
#           data_emprestimo          data_devolucao matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662       2008023265.0
# 1 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662       2008023265.0
# 2 2010-03-01 12:40:56.212 2010-04-30 14:42:35.366       2009121584.0
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 2  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
#
#                        biblioteca status_material  localizacao  \
# 0  Biblioteca Central Zila Mamede         REGULAR          630
# 1  Biblioteca Central Zila Mamede         REGULAR          630
# ...

# %%
dados.shape
# Out:
# (2072558, 13)

# %%
dados.isna().sum()
# Out:
# id_emprestimo                 0
# codigo_barras                 0
# data_renovacao          1162088
# data_emprestimo               0
# data_devolucao             6178
# matricula_ou_siape            0
# tipo_vinculo_usuario          0
# id_exemplar                   0
# colecao                       0
# biblioteca                    0
# status_material               0
# localizacao                   0
# registro_sistema              0
# dtype: int64

# %% [markdown]
# # Limpeza:

# %%
dados.id_emprestimo.value_counts()
# Out:
# 709705     7
# 709704     7
# 2422542    6
# 2460196    4
# 2378367    4
#           ..
# 1275779    1
# 1242892    1
# 1122431    1
# 1099303    1
# 2989061    1
# Name: id_emprestimo, Length: 1955945, dtype: int64

# %%
dados.data_emprestimo.value_counts()
# 1942876 2016-05-02 08:22:54       2015041228.0   ALUNO DE GRADUAÇÃO
# 1942877 2016-05-02 08:22:54       2015041228.0   ALUNO DE GRADUAÇÃO
# 1942878 2017-05-02 08:22:54       2015041228.0   ALUNO DE GRADUAÇÃO
# 1942879 2017-05-02 08:22:54       2015041228.0   ALUNO DE GRADUAÇÃO
# ...

# %%
dados.query('id_emprestimo == 2352752')
# Out:
#          id_emprestimo codigo_barras          data_renovacao  \
# 1868642        2352752    2016019472 2016-02-07 13:09:55.390
# 1868643        2352752    2016019472 2016-02-07 13:09:55.390
# 1868666        2352752    2016019472 2017-02-07 13:09:55.390
# 1868667        2352752    2016019472 2017-02-07 13:09:55.390
#
#                 data_emprestimo      data_devolucao matricula_ou_siape  \
# 1868642 2016-01-10 14:34:20.217 2016-02-08 18:09:22       2014109820.0
# 1868643 2016-01-10 14:34:20.217 2016-02-08 18:09:22       2014109820.0
# 1868666 2017-01-10 14:34:20.217 2017-02-08 18:09:22       2014109820.0
# 1868667 2017-01-10 14:34:20.217 2017-02-08 18:09:22       2014109820.0
#
#            tipo_vinculo_usuario  id_exemplar            colecao  \
# 1868642  ALUNO DE PÓS-GRADUAÇÃO      1234310  Acervo Circulante
# 1868643  ALUNO DE PÓS-GRADUAÇÃO      1234422  Acervo Circulante
# 1868666  ALUNO DE PÓS-GRADUAÇÃO      1234310  Acervo Circulante
# ...

# %%
dados.query('id_emprestimo == 2375005')
# Out:
#          id_emprestimo codigo_barras data_renovacao         data_emprestimo  \
# 1800746        2375005    2015008424            NaT 2016-02-23 08:47:09.769
# 1800747        2375005    2015008424            NaT 2016-02-23 08:47:09.769
# 1800756        2375005    2015008424            NaT 2017-02-23 08:47:09.769
# 1800757        2375005    2015008424            NaT 2017-02-23 08:47:09.769
#
#              data_devolucao matricula_ou_siape tipo_vinculo_usuario  \
# 1800746 2016-03-03 08:18:40       2012962072.0   ALUNO DE GRADUAÇÃO
# 1800747 2016-03-03 08:18:40       2012962072.0   ALUNO DE GRADUAÇÃO
# 1800756 2017-03-03 08:18:40       2012962072.0   ALUNO DE GRADUAÇÃO
# 1800757 2017-03-03 08:18:40       2012962072.0   ALUNO DE GRADUAÇÃO
#
#          id_exemplar            colecao  \
# 1800746      1180951  Acervo Circulante
# 1800747      1181550  Acervo Circulante
# 1800756      1180951  Acervo Circulante
# 1800757      1181550  Acervo Circulante
#
# ...

# %%
dados = dados.drop_duplicates()
dados
# Out:
#          id_emprestimo codigo_barras          data_renovacao  \
# 0               709684       L095049                     NaT
# 2               726965       L095049 2010-03-31 12:41:08.684
# 3               709685       L167050                     NaT
# 5               717763       L167050                     NaT
# 6               729996       L167050 2010-03-17 09:08:26.874
# ...                ...           ...                     ...
# 2072553        2989018    2009036492                     NaT
# 2072554        2989020    2014062640                     NaT
# 2072555        2989032    2018003324                     NaT
# 2072556        2989049    2006024313                     NaT
# 2072557        2989061    2018031352                     NaT
#
#                 data_emprestimo          data_devolucao matricula_ou_siape  \
# 0       2010-01-04 07:44:10.721 2010-01-05 16:26:12.662       2008023265.0
# 2       2010-03-01 12:40:56.212 2010-04-30 14:42:35.366       2009121584.0
# ...
